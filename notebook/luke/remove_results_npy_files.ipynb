# %%
PROJECT_PATH = "/Users/lukefoster/Documents/CompEtho/BM_GPU"

FILE_PATH = f"{PROJECT_PATH}/results/final_prac"

# %%
from os import listdir
from os.path import isfile
import os

# %%
tot_files = [f for f in listdir(f"{FILE_PATH}")]
tot_folders = []

for file in tot_files:
    if "." not in file:
        tot_folders.append(file)

#print(len(tot_files))
#print(len(tot_folders))

# %%
for i, folder in enumerate(tot_folders):
    
    print(f"\n**FOLDER {tot_folders[i]}:")
    
    # remove all_embeddings.npy
    try:
        os.remove(f"{FILE_PATH}/{tot_folders[i]}/all_embeddings.npy")
    except:
        print("ERROR: unable to delete all_embeddings.npy")
    
    # remove all_kinematic_embeddings.npy
    try:
        os.remove(f"{FILE_PATH}/{tot_folders[i]}/all_kinematic_embeddings.npy")
    except:
        print("ERROR: unable to delete all_kinematic_embeddings.npy")
    
    # remove all_postural_embeddings.npy
    try:
        os.remove(f"{FILE_PATH}/{tot_folders[i]}/all_postural_embeddings.npy")
    except:
        print("ERROR: unable to delete all_postural_embeddings.npy")
        
    # remove angle_power.npy
    try:
        os.remove(f"{FILE_PATH}/{tot_folders[i]}/angle_power.npy")
    except:
        print("ERROR: unable to delete angle_power.npy")
    
    # remove angles.npy
    try:
        os.remove(f"{FILE_PATH}/{tot_folders[i]}/angles.npy")
    except:
        print("ERROR: unable to delete angles.npy")
        
    # remove cluster.npy
    try:
        os.remove(f"{FILE_PATH}/{tot_folders[i]}/cluster.npy")
    except:
        print("ERROR: unable to delete cluster.npy")
    
    # remove limbs.npy
    try:
        os.remove(f"{FILE_PATH}/{tot_folders[i]}/limbs.npy")
    except:
        print("ERROR: unable to delete limbs.npy")
    
    # remove limb_power.npy
    try:
        os.remove(f"{FILE_PATH}/{tot_folders[i]}/limb_power.npy")
    except:
        print("ERROR: unable to delete limb_power.npy")
# Out:
# **FOLDER 09BRmajfd_antmovie200928220236:
# ERROR: unable to delete all_embeddings.npy
# ERROR: unable to delete all_kinematic_embeddings.npy
# ERROR: unable to delete all_postural_embeddings.npy
# ERROR: unable to delete angle_power.npy
# ERROR: unable to delete angles.npy
# ERROR: unable to delete cluster.npy
# ERROR: unable to delete limbs.npy
# ERROR: unable to delete limb_power.npy
#
# **FOLDER 04YWmajfd_antmovie200928202317:
# ERROR: unable to delete all_embeddings.npy
# ERROR: unable to delete all_kinematic_embeddings.npy
# ERROR: unable to delete all_postural_embeddings.npy
# ERROR: unable to delete angle_power.npy
# ERROR: unable to delete angles.npy
# ERROR: unable to delete cluster.npy
# ERROR: unable to delete limbs.npy
# ERROR: unable to delete limb_power.npy
#
# **FOLDER 09BRmajfr_antmovie200928215349:
# ERROR: unable to delete all_embeddings.npy
# ERROR: unable to delete all_kinematic_embeddings.npy
# ERROR: unable to delete all_postural_embeddings.npy
# ...
